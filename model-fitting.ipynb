# %%
# Imports
import pandas as pd
from sklearn.model_selection import train_test_split
pd.options.mode.chained_assignment = None

# Get data
data = pd.read_csv('data/song_data_clean.csv')

# Training toward song length
X = data.copy().drop(columns=['Length (Duration)'])
y = data['Length (Duration)'].copy()

# Get a 30%/70% train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=3)

# %%
# Get descriptive statistics of training set: X
X_train.describe()
# Out:
#         Unnamed: 0  Beats Per Minute (BPM)       Energy  Loudness (dB)  \
# count  1390.000000             1390.000000  1390.000000    1390.000000
# mean    998.934532              119.513456    59.577394      -9.052553
# std     569.273209               28.351264    22.250298       3.702116
# min       0.000000               15.000000     3.000000     -27.000000
# 25%     512.250000               98.000000    42.000000     -11.000000
# 50%    1002.000000              119.000000    61.000000      -9.000000
# 75%    1488.750000              136.000000    77.000000      -6.000000
# max    1992.000000              297.000000   100.000000      -2.000000
#
#           Liveness  Acousticness  Speechiness   Popularity  \
# count  1390.000000   1390.000000  1390.000000  1390.000000
# mean     19.158302     28.325839     4.939568    59.452518
# std      16.736022     28.849817     4.029492    14.345535
# min       2.000000      0.000000     2.000000    11.000000
# ...

# %%
# Get descriptive statistics of testing set: X
X_test.describe()
# Out:
#         Unnamed: 0  Beats Per Minute (BPM)      Energy  Loudness (dB)  \
# count   596.000000              596.000000  596.000000     596.000000
# mean    987.827181              121.916107   59.800336      -8.931235
# std     591.916760               29.186385   21.931491       3.522361
# min       1.000000               37.000000    6.000000     -24.000000
# 25%     457.750000              100.750000   43.000000     -11.000000
# 50%     983.500000              120.000000   61.000000      -8.000000
# 75%    1504.750000              136.250000   78.000000      -6.000000
# max    1993.000000              305.000000   99.000000      -2.000000
#
#          Liveness  Acousticness  Speechiness  Popularity  \
# count  596.000000    596.000000    596.00000  596.000000
# mean    18.696342     30.295162      5.11408   59.650188
# std     16.751372     29.372091      5.18340   14.415054
# min      2.000000      0.000000      2.00000   14.000000
# ...

# %%
# Get descriptive statistics of training set: y
y_train.describe()
# Out:
# count    1390.000000
# mean      263.845216
# std        92.124784
# min        93.000000
# 25%       214.000000
# 50%       249.000000
# 75%       291.000000
# max      1412.000000
# Name: Length (Duration), dtype: float64

# %%
# Get descriptive statistics of testing set: y
y_test.describe()
# Out:
# count     596.000000
# mean      259.751034
# std        97.374206
# min       108.000000
# 25%       208.750000
# 50%       241.000000
# 75%       283.250000
# max      1292.000000
# Name: Length (Duration), dtype: float64
