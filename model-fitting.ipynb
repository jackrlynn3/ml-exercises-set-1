# %%
# Imports
import pandas as pd
from sklearn.model_selection import train_test_split
pd.options.mode.chained_assignment = None

# Get data
data = pd.read_csv('data/song_data_clean.csv')

# Training toward song length
X = data.copy().drop(columns=['Length (Duration)'])
y = data['Length (Duration)'].copy()

# Get a 30%/70% train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Get descriptive statistics of training set: X
X_train.describe()
# Out:
#         Unnamed: 0  Beats Per Minute (BPM)       Energy  Loudness (dB)  \
# count  1390.000000             1390.000000  1390.000000    1390.000000
# mean    998.917266                0.025812    -0.008391      -0.003670
# std     573.984634                1.014911     0.990681       0.997668
# min       0.000000               -3.678105    -2.467652      -4.930159
# 25%     504.250000               -0.742178    -0.751631      -0.543861
# 50%     992.000000               -0.008196     0.016063       0.278570
# 75%    1491.750000                0.551028     0.783757       0.826857
# max    1992.000000                6.457834     1.777243       1.923432
#
#           Liveness  Acousticness  Speechiness   Popularity          Age  \
# count  1390.000000   1390.000000  1390.000000  1390.000000  1390.000000
# mean      0.009962      0.021144    -0.005520    -0.010969    -0.002308
# std       1.010300      1.011555     0.948934     0.994524     1.005049
# min      -0.957339     -0.996896    -0.679078    -3.378387    -1.641680
# 25%      -0.598778     -0.858998    -0.452109    -0.732049    -0.908897
# 50%      -0.419497     -0.341879    -0.225140     0.173277    -0.020943
# 75%       0.237866      0.761308     0.001829     0.730400     0.886174
# max       4.660123      2.381614     9.307566     2.819614     2.178083
#
#        Top Genre_acoustic pop  ...  Top Genre_reggae  Top Genre_reggae fusion  \
# count             1390.000000  ...       1390.000000              1390.000000
# mean                 0.001439  ...          0.003597                 0.002878
# std                  0.037919  ...          0.059890                 0.053586
# min                  0.000000  ...          0.000000                 0.000000
# 25%                  0.000000  ...          0.000000                 0.000000
# 50%                  0.000000  ...          0.000000                 0.000000
# 75%                  0.000000  ...          0.000000                 0.000000
# max                  1.000000  ...          1.000000                 1.000000
#
#        Top Genre_rock-and-roll  Top Genre_scottish singer-songwriter  \
# count              1390.000000                           1390.000000
# mean                  0.000719                              0.000719
# std                   0.026822                              0.026822
# min                   0.000000                              0.000000
# 25%                   0.000000                              0.000000
# 50%                   0.000000                              0.000000
# 75%                   0.000000                              0.000000
# max                   1.000000                              1.000000
#
#        Top Genre_soft rock  Top Genre_stomp and holler  Top Genre_streektaal  \
# count          1390.000000                      1390.0           1390.000000
# mean              0.000719                         0.0              0.000719
# std               0.026822                         0.0              0.026822
# min               0.000000                         0.0              0.000000
# 25%               0.000000                         0.0              0.000000
# 50%               0.000000                         0.0              0.000000
# 75%               0.000000                         0.0              0.000000
# max               1.000000                         0.0              1.000000
#
#        Top Genre_trance  Top Genre_uk pop  Top Genre_yacht rock
# count       1390.000000            1390.0           1390.000000
# mean           0.000719               0.0              0.000719
# std            0.026822               0.0              0.026822
# min            0.000000               0.0              0.000000
# 25%            0.000000               0.0              0.000000
# 50%            0.000000               0.0              0.000000
# 75%            0.000000               0.0              0.000000
# max            1.000000               0.0              1.000000
#
# [8 rows x 157 columns]

# %%
# Get descriptive statistics of testing set: X
X_test.describe()
# Out:
#         Unnamed: 0  Beats Per Minute (BPM)      Energy  Loudness (dB)  \
# count   596.000000              596.000000  596.000000     596.000000
# mean    987.867450               -0.060199    0.019570       0.008558
# std     581.198852                0.963346    1.022801       1.007040
# min       1.000000               -3.573250   -2.557969      -3.559441
# 25%     478.750000               -0.777129   -0.841948      -0.543861
# 50%    1001.000000               -0.113050    0.151538       0.004426
# 75%    1498.250000                0.516077    0.828915       0.826857
# max    1993.000000                2.718022    1.822401       1.923432
#
#          Liveness  Acousticness  Speechiness  Popularity         Age  \
# count  596.000000    596.000000   596.000000  596.000000  596.000000
# mean    -0.023232     -0.049312     0.012873    0.025583    0.005384
# std      0.976858      0.972429     1.111512    1.013865    0.989791
# min     -1.017099     -0.996896    -0.679078   -2.960544   -1.641680
# 25%     -0.598778     -0.893472    -0.452109   -0.662409   -0.853061
# 50%     -0.359737     -0.445303    -0.225140    0.173277   -0.023572
# 75%      0.178105      0.588935     0.001829    0.869681    0.842379
# max      4.779644      2.416089    11.350289    2.471412    2.281192
#
#        Top Genre_acoustic pop  ...  Top Genre_reggae  Top Genre_reggae fusion  \
# count              596.000000  ...        596.000000                    596.0
# mean                 0.003356  ...          0.005034                      0.0
# std                  0.057880  ...          0.070828                      0.0
# min                  0.000000  ...          0.000000                      0.0
# 25%                  0.000000  ...          0.000000                      0.0
# 50%                  0.000000  ...          0.000000                      0.0
# 75%                  0.000000  ...          0.000000                      0.0
# max                  1.000000  ...          1.000000                      0.0
#
#        Top Genre_rock-and-roll  Top Genre_scottish singer-songwriter  \
# count                    596.0                            596.000000
# mean                       0.0                              0.001678
# std                        0.0                              0.040962
# min                        0.0                              0.000000
# 25%                        0.0                              0.000000
# 50%                        0.0                              0.000000
# 75%                        0.0                              0.000000
# max                        0.0                              1.000000
#
#        Top Genre_soft rock  Top Genre_stomp and holler  Top Genre_streektaal  \
# count                596.0                  596.000000                 596.0
# mean                   0.0                    0.001678                   0.0
# std                    0.0                    0.040962                   0.0
# min                    0.0                    0.000000                   0.0
# 25%                    0.0                    0.000000                   0.0
# 50%                    0.0                    0.000000                   0.0
# 75%                    0.0                    0.000000                   0.0
# max                    0.0                    1.000000                   0.0
#
#        Top Genre_trance  Top Genre_uk pop  Top Genre_yacht rock
# count             596.0        596.000000                 596.0
# mean                0.0          0.001678                   0.0
# std                 0.0          0.040962                   0.0
# min                 0.0          0.000000                   0.0
# 25%                 0.0          0.000000                   0.0
# 50%                 0.0          0.000000                   0.0
# 75%                 0.0          0.000000                   0.0
# max                 0.0          1.000000                   0.0
#
# [8 rows x 157 columns]

# %%
# Get descriptive statistics of training set: y
y_train.describe()
# Out:
# count    1390.000000
# mean        0.006666
# std         1.063343
# min        -1.810179
# 25%        -0.550861
# 50%        -0.188007
# 75%         0.289573
# max        12.266432
# Name: Length (Duration), dtype: float64

# %%
# Get descriptive statistics of testing set: y
y_test.describe()
# Out:
# count    596.000000
# mean      -0.015547
# std        0.835407
# min       -1.714129
# 25%       -0.518845
# 50%       -0.150654
# 75%        0.292241
# max        5.852449
# Name: Length (Duration), dtype: float64
