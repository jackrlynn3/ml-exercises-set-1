# %% [markdown]
# # **Exercise:** *Data Processing*
# ### July 18, 2022

# %%
# Imports
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from config import ml_songs_data
from datetime import datetime
from datetime import timedelta
from sklearn.preprocessing import StandardScaler
pd.options.mode.chained_assignment = None

# Get raw data
raw_song_data = pd.read_csv(ml_songs_data)

# Check data types
raw_song_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   1994 non-null   int64
#  1   Title                   1991 non-null   object
#  2   Artist                  1986 non-null   object
#  3   Top Genre               1986 non-null   object
#  4   Year                    1987 non-null   float64
#  5   Month                   1994 non-null   object
#  6   Beats Per Minute (BPM)  1985 non-null   float64
#  7   Energy                  1986 non-null   float64
#  8   Danceability            970 non-null    float64
#  9   Loudness (dB)           1987 non-null   float64
#  10  Liveness                1986 non-null   float64
#  11  Valence                 960 non-null    float64
#  12  Length (Duration)       1985 non-null   object
#  13  Acousticness            1986 non-null   float64
#  14  Speechiness             1990 non-null   float64
#  15  Popularity              1987 non-null   float64
# dtypes: float64(10), int64(1), object(5)
# memory usage: 249.4+ KB

# %%
# Remove rows and columns with less than 50% values
essential_song_data = raw_song_data.copy()

# Remove columns with less than 50% of values
remove_cols = []
for i in range(len(essential_song_data.columns)):
    if (essential_song_data[essential_song_data.columns[i]].isna().sum() >= len(essential_song_data)/2):
        remove_cols.append(essential_song_data.columns[i])
essential_song_data = essential_song_data.drop(columns=remove_cols)

# Remove rows with less than 50% of values
remove_rows = []
for i in range(len(essential_song_data)):
    if (essential_song_data.iloc[i].isna().sum() >= len(essential_song_data.columns)/2):
        remove_rows.append(i)
essential_song_data = essential_song_data.drop(index=remove_rows)

# %%
# Fix data hygiene typing issues
hygienic_song_data = essential_song_data.copy()

# Remove Title, Artist, and Index because it will not be easily passed in ML algorithm
hygienic_song_data = hygienic_song_data.drop(columns=['Title', 'Artist', 'Index'])

# Convert all month variables into ints
month_dict = {'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
    'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12}
hygienic_song_data['Month'] = hygienic_song_data['Month'].replace(month_dict)
hygienic_song_data['Month'] = hygienic_song_data['Month'].astype(int)

# Remove commas from Length Duration and cast as integer
hygienic_song_data['Length (Duration)'][hygienic_song_data['Length (Duration)'].notna()] = hygienic_song_data['Length (Duration)'][hygienic_song_data['Length (Duration)'].notna()].str.replace(',', '')
hygienic_song_data['Length (Duration)'][hygienic_song_data['Length (Duration)'].notna()] = hygienic_song_data['Length (Duration)'][hygienic_song_data['Length (Duration)'].notna()].astype(int)

# Pass all numeric data through mean imputation
imputer_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
numeric_data = hygienic_song_data.copy()
numeric_data = numeric_data.drop(columns='Top Genre')
imputer_mean.fit(numeric_data)
numeric_data[:] = imputer_mean.transform(numeric_data)

# Add age 
numeric_data['Year'][numeric_data['Year'] == 92] = 1992
numeric_data['Age'] = 0
for i in range(len(numeric_data)):
    numeric_data['Age'].iloc[i] = (datetime.now() - pd.to_datetime(f'{int(numeric_data["Year"].iloc[i])}-{int(numeric_data["Month"].iloc[i])}-1', yearfirst=True)) / timedelta(days=365)
numeric_data = numeric_data.drop(columns=['Year', 'Month'])

# NEW: convert to standard z-scores
ss = StandardScaler()
ss.fit(numeric_data)
numeric_data[:] = ss.transform(numeric_data)

# Pass all categorical data through mode imputation
imputer_mode = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
categorical_data = pd.DataFrame(hygienic_song_data['Top Genre'].copy())
imputer_mode.fit(categorical_data)
categorical_data[:] = imputer_mode.transform(categorical_data)
categorical_data = pd.get_dummies(categorical_data, drop_first=True)

# Put data back together
hygienic_song_data = pd.concat([numeric_data, categorical_data], axis=1)

# %%
# View characteristics of numerical data
hygienic_song_data.describe()
# Out:
#        Beats Per Minute (BPM)        Energy  Loudness (dB)      Liveness  \
# count            1.986000e+03  1.986000e+03   1.986000e+03  1.986000e+03
# mean             7.871068e-17 -2.826429e-16  -2.289765e-16 -4.829973e-17
# std              1.000252e+00  1.000252e+00   1.000252e+00  1.000252e+00
# min             -3.678105e+00 -2.557969e+00  -4.930159e+00 -1.017099e+00
# 25%             -7.421776e-01 -7.967893e-01  -5.438611e-01 -5.987777e-01
# 50%             -4.314740e-02  6.122138e-02   4.426133e-03 -4.194970e-01
# 75%              5.510283e-01  8.289151e-01   8.268570e-01  2.378656e-01
# max              6.457834e+00  1.822401e+00   1.923432e+00  4.779644e+00
#
#        Length (Duration)  Acousticness   Speechiness    Popularity  \
# count       1.986000e+03  1.986000e+03  1.986000e+03  1.986000e+03
# mean        2.325543e-16 -6.439964e-17  8.586619e-17  4.293310e-17
# std         1.000252e+00  1.000252e+00  1.000252e+00  1.000252e+00
# min        -1.810179e+00 -9.968961e-01 -6.790781e-01 -3.378387e+00
# 25%        -5.401891e-01 -8.934723e-01 -4.521089e-01 -7.320493e-01
# 50%        -1.826710e-01 -3.763534e-01 -2.251397e-01  1.732767e-01
# 75%         2.922412e-01  7.268336e-01  1.829475e-03  8.000408e-01
# max         1.226643e+01  2.416089e+00  1.135029e+01  2.819614e+00
#
#                 Age  Top Genre_acoustic pop  ...  Top Genre_reggae  \
# count  1.986000e+03             1986.000000  ...       1986.000000
# mean  -5.724413e-17                0.002014  ...          0.004028
# std    1.000252e+00                0.044845  ...          0.063356
# min   -1.641680e+00                0.000000  ...          0.000000
# 25%   -8.971112e-01                0.000000  ...          0.000000
# 50%   -2.094323e-02                0.000000  ...          0.000000
# 75%    8.670110e-01                0.000000  ...          0.000000
# max    2.281192e+00                1.000000  ...          1.000000
#
#        Top Genre_reggae fusion  Top Genre_rock-and-roll  \
# count              1986.000000              1986.000000
# mean                  0.002014                 0.000504
# std                   0.044845                 0.022439
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                   1.000000                 1.000000
#
#        Top Genre_scottish singer-songwriter  Top Genre_soft rock  \
# count                           1986.000000          1986.000000
# mean                               0.001007             0.000504
# std                                0.031726             0.022439
# min                                0.000000             0.000000
# 25%                                0.000000             0.000000
# 50%                                0.000000             0.000000
# 75%                                0.000000             0.000000
# max                                1.000000             1.000000
#
#        Top Genre_stomp and holler  Top Genre_streektaal  Top Genre_trance  \
# count                 1986.000000           1986.000000       1986.000000
# mean                     0.000504              0.000504          0.000504
# std                      0.022439              0.022439          0.022439
# min                      0.000000              0.000000          0.000000
# 25%                      0.000000              0.000000          0.000000
# 50%                      0.000000              0.000000          0.000000
# 75%                      0.000000              0.000000          0.000000
# max                      1.000000              1.000000          1.000000
#
#        Top Genre_uk pop  Top Genre_yacht rock
# count       1986.000000           1986.000000
# mean           0.000504              0.000504
# std            0.022439              0.022439
# min            0.000000              0.000000
# 25%            0.000000              0.000000
# 50%            0.000000              0.000000
# 75%            0.000000              0.000000
# max            1.000000              1.000000
#
# [8 rows x 157 columns]

# %%
# Find outliers
def findOutliers(column):
    
    # Get mean and SD
    mean = column.mean()
    std = column.std()

    # Get list of outliers (i.e., 3 STD from total)
    outliers = []
    for i in range(len(column)):
        val = column.iloc[i]
        if (val < mean - 3 * std or val > mean + 3 * std):
            outliers.append(i)
    
    # Return outlier indices
    return outliers

# %%
# Get mean, std, and outliers for each column
for column in hygienic_song_data.columns:
    print(f'  Column: {column}')
    print(f'    Mean: {hygienic_song_data[column].mean()}')
    print(f'     STD: {hygienic_song_data[column].std()}')
    print(f'Outliers: {len(findOutliers(hygienic_song_data[column]))}')
    print()
# Out:
#   Column: Beats Per Minute (BPM)
#     Mean: 7.87106756632538e-17
#      STD: 1.0002518574526775
# Outliers: 4
#
#   Column: Energy
#     Mean: -2.82642880790775e-16
#      STD: 1.0002518574526775
# Outliers: 0
#
#   Column: Loudness (dB)
#     Mean: -2.289765110203747e-16
#      STD: 1.0002518574526775
# Outliers: 22
#
#   Column: Liveness
#     Mean: -4.829973279336028e-17
#      STD: 1.0002518574526775
# Outliers: 57
#
#   Column: Length (Duration)
#     Mean: 2.3255426900506804e-16
#      STD: 1.0002518574526775
# Outliers: 26
#
#   Column: Acousticness
#     Mean: -6.439964372448039e-17
#      STD: 1.0002518574526775
# Outliers: 0
#
#   Column: Speechiness
#     Mean: 8.58661916326405e-17
#      STD: 1.0002518574526773
# Outliers: 42
#
#   Column: Popularity
#     Mean: 4.293309581632025e-17
#      STD: 1.0002518574526775
# Outliers: 9
#
#   Column: Age
#     Mean: -5.724412775509367e-17
#      STD: 1.0002518574526775
# Outliers: 0
#
#   Column: Top Genre_acoustic pop
#     Mean: 0.002014098690835851
#      STD: 0.04484478467966559
# Outliers: 4
#
#   Column: Top Genre_adult standards
#     Mean: 0.06092648539778449
#      STD: 0.23925566278511493
# Outliers: 121
#
#   Column: Top Genre_afropop
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_alaska indie
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_album rock
#     Mean: 0.2079556898288016
#      STD: 0.4059471619404535
# Outliers: 0
#
#   Column: Top Genre_alternative country
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_alternative dance
#     Mean: 0.0075528700906344415
#      STD: 0.08660023370583089
# Outliers: 15
#
#   Column: Top Genre_alternative hip hop
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_alternative metal
#     Mean: 0.03423967774420947
#      STD: 0.18189002395071818
# Outliers: 68
#
#   Column: Top Genre_alternative pop
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_alternative pop rock
#     Mean: 0.003524672708962739
#      STD: 0.05927915979850556
# Outliers: 7
#
#   Column: Top Genre_alternative rock
#     Mean: 0.042799597180261835
#      STD: 0.20245599607678877
# Outliers: 85
#
#   Column: Top Genre_arkansas country
#     Mean: 0.004531722054380665
#      STD: 0.06718227584087175
# Outliers: 9
#
#   Column: Top Genre_art pop
#     Mean: 0.007049345417925478
#      STD: 0.08368499519164843
# Outliers: 14
#
#   Column: Top Genre_art rock
#     Mean: 0.02014098690835851
#      STD: 0.14051786286882528
# Outliers: 40
#
#   Column: Top Genre_atl hip hop
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_australian alternative rock
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_australian americana
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_australian dance
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_australian indie folk
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_australian pop
#     Mean: 0.004028197381671702
#      STD: 0.06335607430712852
# Outliers: 8
#
#   Column: Top Genre_australian psych
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_australian rock
#     Mean: 0.0015105740181268882
#      STD: 0.03884651888125559
# Outliers: 3
#
#   Column: Top Genre_austropop
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_barbadian pop
#     Mean: 0.0015105740181268882
#      STD: 0.038846518881255586
# Outliers: 3
#
#   Column: Top Genre_baroque pop
#     Mean: 0.0030211480362537764
#      STD: 0.05489570194084483
# Outliers: 6
#
#   Column: Top Genre_basshall
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_bebop
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_belgian pop
#     Mean: 0.002014098690835851
#      STD: 0.0448447846796656
# Outliers: 4
#
#   Column: Top Genre_belgian rock
#     Mean: 0.004028197381671702
#      STD: 0.06335607430712852
# Outliers: 8
#
#   Column: Top Genre_big beat
#     Mean: 0.0055387713997985906
#      STD: 0.07423522256530934
# Outliers: 11
#
#   Column: Top Genre_big room
#     Mean: 0.003524672708962739
#      STD: 0.05927915979850555
# Outliers: 7
#
#   Column: Top Genre_blues
#     Mean: 0.004028197381671702
#      STD: 0.06335607430712852
# Outliers: 8
#
#   Column: Top Genre_blues rock
#     Mean: 0.0075528700906344415
#      STD: 0.08660023370583089
# Outliers: 15
#
#   Column: Top Genre_bow pop
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_boy band
#     Mean: 0.0030211480362537764
#      STD: 0.05489570194084483
# Outliers: 6
#
#   Column: Top Genre_brill building pop
#     Mean: 0.0030211480362537764
#      STD: 0.05489570194084483
# Outliers: 6
#
#   Column: Top Genre_british alternative rock
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_british folk
#     Mean: 0.002014098690835851
#      STD: 0.04484478467966559
# Outliers: 4
#
#   Column: Top Genre_british invasion
#     Mean: 0.01812688821752266
#      STD: 0.13344388536438515
# Outliers: 36
#
#   Column: Top Genre_british singer-songwriter
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_british soul
#     Mean: 0.015609264853977844
#      STD: 0.12398934054599646
# Outliers: 31
#
#   Column: Top Genre_britpop
#     Mean: 0.0055387713997985906
#      STD: 0.07423522256530934
# Outliers: 11
#
#   Column: Top Genre_bubblegum pop
#     Mean: 0.0015105740181268882
#      STD: 0.03884651888125559
# Outliers: 3
#
#   Column: Top Genre_canadian folk
#     Mean: 0.003524672708962739
#      STD: 0.05927915979850556
# Outliers: 7
#
#   Column: Top Genre_canadian pop
#     Mean: 0.0025176233635448137
#      STD: 0.05012534356086098
# Outliers: 5
#
#   Column: Top Genre_canadian rock
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_candy pop
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062367
# Outliers: 2
#
#   Column: Top Genre_carnaval limburg
#     Mean: 0.005035246727089627
#      STD: 0.07079842436850216
# Outliers: 10
#
#   Column: Top Genre_ccm
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_celtic
#     Mean: 0.0025176233635448137
#      STD: 0.05012534356086098
# Outliers: 5
#
#   Column: Top Genre_celtic punk
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_celtic rock
#     Mean: 0.003524672708962739
#      STD: 0.05927915979850555
# Outliers: 7
#
#   Column: Top Genre_chamber pop
#     Mean: 0.003524672708962739
#      STD: 0.05927915979850555
# Outliers: 7
#
#   Column: Top Genre_chanson
#     Mean: 0.004531722054380665
#      STD: 0.06718227584087175
# Outliers: 9
#
#   Column: Top Genre_chicago soul
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_christelijk
#     Mean: 0.0015105740181268882
#      STD: 0.038846518881255586
# Outliers: 3
#
#   Column: Top Genre_classic canadian rock
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260013
# Outliers: 1
#
#   Column: Top Genre_classic country pop
#     Mean: 0.0025176233635448137
#      STD: 0.05012534356086097
# Outliers: 5
#
#   Column: Top Genre_classic italian pop
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_classic rock
#     Mean: 0.0256797583081571
#      STD: 0.1582179288535987
# Outliers: 51
#
#   Column: Top Genre_classic schlager
#     Mean: 0.0015105740181268882
#      STD: 0.038846518881255586
# Outliers: 3
#
#   Column: Top Genre_classic soul
#     Mean: 0.0055387713997985906
#      STD: 0.07423522256530936
# Outliers: 11
#
#   Column: Top Genre_classic soundtrack
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_classic uk pop
#     Mean: 0.011077542799597181
#      STD: 0.10469168855067419
# Outliers: 22
#
#   Column: Top Genre_classical rock
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_compositional ambient
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_contemporary country
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062367
# Outliers: 2
#
#   Column: Top Genre_contemporary vocal jazz
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_cyberpunk
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_dance pop
#     Mean: 0.041289023162134945
#      STD: 0.19900799333427407
# Outliers: 82
#
#   Column: Top Genre_dance rock
#     Mean: 0.0256797583081571
#      STD: 0.1582179288535987
# Outliers: 51
#
#   Column: Top Genre_danish pop
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_danish pop rock
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_detroit hip hop
#     Mean: 0.003524672708962739
#      STD: 0.05927915979850555
# Outliers: 7
#
#   Column: Top Genre_disco
#     Mean: 0.00906344410876133
#      STD: 0.09479357928187522
# Outliers: 18
#
#   Column: Top Genre_diva house
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260013
# Outliers: 1
#
#   Column: Top Genre_downtempo
#     Mean: 0.002014098690835851
#      STD: 0.04484478467966559
# Outliers: 4
#
#   Column: Top Genre_dutch americana
#     Mean: 0.006042296072507553
#      STD: 0.07751652930784804
# Outliers: 12
#
#   Column: Top Genre_dutch cabaret
#     Mean: 0.025176233635448138
#      STD: 0.1566995686664957
# Outliers: 50
#
#   Column: Top Genre_dutch hip hop
#     Mean: 0.006545820745216516
#      STD: 0.08066132302970776
# Outliers: 13
#
#   Column: Top Genre_dutch indie
#     Mean: 0.0377643504531722
#      STD: 0.19067383325503084
# Outliers: 75
#
#   Column: Top Genre_dutch metal
#     Mean: 0.002014098690835851
#      STD: 0.04484478467966559
# Outliers: 4
#
#   Column: Top Genre_dutch pop
#     Mean: 0.044310171198388724
#      STD: 0.20583516054636902
# Outliers: 88
#
#   Column: Top Genre_dutch prog
#     Mean: 0.0025176233635448137
#      STD: 0.05012534356086097
# Outliers: 5
#
#   Column: Top Genre_dutch rock
#     Mean: 0.00906344410876133
#      STD: 0.09479357928187522
# Outliers: 18
#
#   Column: Top Genre_east coast hip hop
#     Mean: 0.0030211480362537764
#      STD: 0.05489570194084483
# Outliers: 6
#
#   Column: Top Genre_edm
#     Mean: 0.0015105740181268882
#      STD: 0.03884651888125559
# Outliers: 3
#
#   Column: Top Genre_electro
#     Mean: 0.003524672708962739
#      STD: 0.05927915979850555
# Outliers: 7
#
#   Column: Top Genre_electro house
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_electronica
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_electropop
#     Mean: 0.0015105740181268882
#      STD: 0.038846518881255586
# Outliers: 3
#
#   Column: Top Genre_eurodance
#     Mean: 0.0015105740181268882
#      STD: 0.03884651888125559
# Outliers: 3
#
#   Column: Top Genre_europop
#     Mean: 0.013595166163141994
#      STD: 0.1158321779892382
# Outliers: 27
#
#   Column: Top Genre_finnish metal
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_folk
#     Mean: 0.004028197381671702
#      STD: 0.06335607430712852
# Outliers: 8
#
#   Column: Top Genre_folk-pop
#     Mean: 0.002014098690835851
#      STD: 0.04484478467966559
# Outliers: 4
#
#   Column: Top Genre_funk
#     Mean: 0.006545820745216516
#      STD: 0.08066132302970776
# Outliers: 13
#
#   Column: Top Genre_g funk
#     Mean: 0.0025176233635448137
#      STD: 0.05012534356086098
# Outliers: 5
#
#   Column: Top Genre_gabba
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_gangster rap
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_garage rock
#     Mean: 0.002014098690835851
#      STD: 0.04484478467966559
# Outliers: 4
#
#   Column: Top Genre_german alternative rock
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_german pop
#     Mean: 0.004531722054380665
#      STD: 0.06718227584087175
# Outliers: 9
#
#   Column: Top Genre_german pop rock
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_glam metal
#     Mean: 0.008559919436052367
#      STD: 0.09214620233263007
# Outliers: 17
#
#   Column: Top Genre_glam rock
#     Mean: 0.024672708962739175
#      STD: 0.15516471667284457
# Outliers: 49
#
#   Column: Top Genre_happy hardcore
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_hard rock
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_hip pop
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_icelandic indie
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_indie anthem-folk
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_indie pop
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_irish pop
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_irish rock
#     Mean: 0.017119838872104734
#      STD: 0.12975063368335998
# Outliers: 34
#
#   Column: Top Genre_irish singer-songwriter
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_italian pop
#     Mean: 0.0015105740181268882
#      STD: 0.038846518881255586
# Outliers: 3
#
#   Column: Top Genre_j-core
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_la pop
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_laboratorio
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_latin
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_latin alternative
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_latin jazz
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_levenslied
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_mellow gold
#     Mean: 0.0055387713997985906
#      STD: 0.07423522256530936
# Outliers: 11
#
#   Column: Top Genre_metropopolis
#     Mean: 0.002014098690835851
#      STD: 0.0448447846796656
# Outliers: 4
#
#   Column: Top Genre_modern folk rock
#     Mean: 0.003524672708962739
#      STD: 0.05927915979850556
# Outliers: 7
#
#   Column: Top Genre_modern rock
#     Mean: 0.024672708962739175
#      STD: 0.15516471667284454
# Outliers: 49
#
#   Column: Top Genre_motown
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_nederpop
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_neo mellow
#     Mean: 0.008559919436052367
#      STD: 0.09214620233263007
# Outliers: 17
#
#   Column: Top Genre_neo soul
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_new wave pop
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_operatic pop
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_permanent wave
#     Mean: 0.019133937562940583
#      STD: 0.1370302332424224
# Outliers: 38
#
#   Column: Top Genre_pop
#     Mean: 0.02366565961732125
#      STD: 0.1520435341309378
# Outliers: 47
#
#   Column: Top Genre_pop punk
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_punk
#     Mean: 0.0010070493454179255
#      STD: 0.03172604633062366
# Outliers: 2
#
#   Column: Top Genre_reggae
#     Mean: 0.004028197381671702
#      STD: 0.06335607430712852
# Outliers: 8
#
#   Column: Top Genre_reggae fusion
#     Mean: 0.002014098690835851
#      STD: 0.04484478467966559
# Outliers: 4
#
#   Column: Top Genre_rock-and-roll
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_scottish singer-songwriter
#     Mean: 0.0010070493454179255
#      STD: 0.031726046330623654
# Outliers: 2
#
#   Column: Top Genre_soft rock
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_stomp and holler
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_streektaal
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_trance
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1
#
#   Column: Top Genre_uk pop
#     Mean: 0.0005035246727089627
#      STD: 0.02243935544326001
# Outliers: 1
#
#   Column: Top Genre_yacht rock
#     Mean: 0.0005035246727089627
#      STD: 0.022439355443260006
# Outliers: 1

# %%
# Save data
hygienic_song_data.to_csv('data/song_data_clean.csv')
